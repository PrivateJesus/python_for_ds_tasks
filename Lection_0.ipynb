# %%
a = 5

# %%
a
# Out:
# 5

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
1+199*12343
# Out:
# 2456258

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.cos(range(10)))

# %%
a = np.arange(1,35)
b = 3 * a + 18 / (1+32) * a
plt.plot(a,b)

# %% [markdown]
# # Heading

# %%
## this is probe comment

# %% [markdown]
# i want write smth here

# %%
a = 3
b = 1

# %%
d = a * b - a / b

# %%
print(d)
# Out:
# 0.0

# %%
b = 45

# %%
print(d)
# Out:
# 0.0
